# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Predicting-Mortgage-Approvals-From-Government-Data" data-toc-modified-id="Predicting-Mortgage-Approvals-From-Government-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Predicting Mortgage Approvals From Government Data</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#Acknowledgment" data-toc-modified-id="Acknowledgment-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Acknowledgment</a></span></li></ul></li><li><span><a href="#About-the-Data" data-toc-modified-id="About-the-Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>About the Data</a></span><ul class="toc-item"><li><span><a href="#Features" data-toc-modified-id="Features-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Features</a></span><ul class="toc-item"><li><span><a href="#PROPERTY-LOCATION" data-toc-modified-id="PROPERTY-LOCATION-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>PROPERTY LOCATION</a></span></li><li><span><a href="#LOAN-INFORMATION" data-toc-modified-id="LOAN-INFORMATION-1.2.1.2"><span class="toc-item-num">1.2.1.2&nbsp;&nbsp;</span>LOAN INFORMATION</a></span></li><li><span><a href="#APPLICANT-INFORMATION" data-toc-modified-id="APPLICANT-INFORMATION-1.2.1.3"><span class="toc-item-num">1.2.1.3&nbsp;&nbsp;</span>APPLICANT INFORMATION</a></span></li><li><span><a href="#CENSUS-INFORMATION" data-toc-modified-id="CENSUS-INFORMATION-1.2.1.4"><span class="toc-item-num">1.2.1.4&nbsp;&nbsp;</span>CENSUS INFORMATION</a></span></li><li><span><a href="#TARGET-VARIABLE" data-toc-modified-id="TARGET-VARIABLE-1.2.1.5"><span class="toc-item-num">1.2.1.5&nbsp;&nbsp;</span>TARGET VARIABLE</a></span></li></ul></li></ul></li><li><span><a href="#Performance-Metric" data-toc-modified-id="Performance-Metric-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Performance Metric</a></span><ul class="toc-item"><li><span><a href="#Load-Required-Libraries" data-toc-modified-id="Load-Required-Libraries-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Load Required Libraries</a></span><ul class="toc-item"><li><span><a href="#Import-the-data" data-toc-modified-id="Import-the-data-1.3.1.1"><span class="toc-item-num">1.3.1.1&nbsp;&nbsp;</span>Import the data</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#DATA-EXPLORATION-&amp;-Visualization" data-toc-modified-id="DATA-EXPLORATION-&amp;-Visualization-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>DATA EXPLORATION &amp; Visualization</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Univariate-Analysis-(Categorical-features)-Using-the-unmodified-train_values" data-toc-modified-id="Univariate-Analysis-(Categorical-features)-Using-the-unmodified-train_values-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Univariate Analysis (Categorical features) Using the unmodified train_values</a></span></li><li><span><a href="#Univariate-Analysis-(Numeric-features)-Using-unmodified-train_values" data-toc-modified-id="Univariate-Analysis-(Numeric-features)-Using-unmodified-train_values-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>Univariate Analysis (Numeric features) Using unmodified train_values</a></span></li><li><span><a href="#Bivariate-Analysis-Using-the-merged-Data" data-toc-modified-id="Bivariate-Analysis-Using-the-merged-Data-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>Bivariate Analysis Using the merged Data</a></span><ul class="toc-item"><li><span><a href="#Visualization-of-numeric-features-with-the-target-variable" data-toc-modified-id="Visualization-of-numeric-features-with-the-target-variable-2.0.3.1"><span class="toc-item-num">2.0.3.1&nbsp;&nbsp;</span>Visualization of numeric features with the target variable</a></span></li><li><span><a href="#Loan-acceptance-rates-across-ethnicity-and-gender" data-toc-modified-id="Loan-acceptance-rates-across-ethnicity-and-gender-2.0.3.2"><span class="toc-item-num">2.0.3.2&nbsp;&nbsp;</span>Loan acceptance rates across ethnicity and gender</a></span></li><li><span><a href="#Applicant-income-and-loan-amount" data-toc-modified-id="Applicant-income-and-loan-amount-2.0.3.3"><span class="toc-item-num">2.0.3.3&nbsp;&nbsp;</span>Applicant income and loan amount</a></span></li><li><span><a href="#Loan-acceptance-across-counties-in-state-48" data-toc-modified-id="Loan-acceptance-across-counties-in-state-48-2.0.3.4"><span class="toc-item-num">2.0.3.4&nbsp;&nbsp;</span>Loan acceptance across counties in state 48</a></span></li><li><span><a href="#Loan-types-across-states-looking-just-at-states-2-and-4" data-toc-modified-id="Loan-types-across-states-looking-just-at-states-2-and-4-2.0.3.5"><span class="toc-item-num">2.0.3.5&nbsp;&nbsp;</span>Loan types across states looking just at states 2 and 4</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Data-Cleaning-&amp;-Feature-Engineering" data-toc-modified-id="Data-Cleaning-&amp;-Feature-Engineering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Cleaning &amp; Feature Engineering</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Dealing-with-Missing-Values-in-train-data" data-toc-modified-id="Dealing-with-Missing-Values-in-train-data-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>Dealing with Missing Values in train data</a></span></li><li><span><a href="#Save-the-train-data-with-replaced-missing-values-to-a-csv-file" data-toc-modified-id="Save-the-train-data-with-replaced-missing-values-to-a-csv-file-3.0.0.2"><span class="toc-item-num">3.0.0.2&nbsp;&nbsp;</span>Save the train data with replaced missing values to a csv file</a></span></li><li><span><a href="#Create-a-new-column,-income_to_loan_ratio" data-toc-modified-id="Create-a-new-column,-income_to_loan_ratio-3.0.0.3"><span class="toc-item-num">3.0.0.3&nbsp;&nbsp;</span>Create a new column, income_to_loan_ratio</a></span></li><li><span><a href="#Correlation-and-heatmap-for-df_clean-data" data-toc-modified-id="Correlation-and-heatmap-for-df_clean-data-3.0.0.4"><span class="toc-item-num">3.0.0.4&nbsp;&nbsp;</span>Correlation and heatmap for df_clean data</a></span></li></ul></li></ul></li><li><span><a href="#Model-Building-and-Selection" data-toc-modified-id="Model-Building-and-Selection-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Model Building and Selection</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-3.1.0.1"><span class="toc-item-num">3.1.0.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#DecisionTreeClassifier" data-toc-modified-id="DecisionTreeClassifier-3.1.0.2"><span class="toc-item-num">3.1.0.2&nbsp;&nbsp;</span>DecisionTreeClassifier</a></span></li><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-3.1.0.3"><span class="toc-item-num">3.1.0.3&nbsp;&nbsp;</span>RandomForestClassifier</a></span></li><li><span><a href="#GradientBoostingClassifier" data-toc-modified-id="GradientBoostingClassifier-3.1.0.4"><span class="toc-item-num">3.1.0.4&nbsp;&nbsp;</span>GradientBoostingClassifier</a></span></li><li><span><a href="#xgboost" data-toc-modified-id="xgboost-3.1.0.5"><span class="toc-item-num">3.1.0.5&nbsp;&nbsp;</span>xgboost</a></span></li><li><span><a href="#lightgbm" data-toc-modified-id="lightgbm-3.1.0.6"><span class="toc-item-num">3.1.0.6&nbsp;&nbsp;</span>lightgbm</a></span></li><li><span><a href="#Chosen-Model" data-toc-modified-id="Chosen-Model-3.1.0.7"><span class="toc-item-num">3.1.0.7&nbsp;&nbsp;</span>Chosen Model</a></span></li><li><span><a href="#Catboost" data-toc-modified-id="Catboost-3.1.0.8"><span class="toc-item-num">3.1.0.8&nbsp;&nbsp;</span>Catboost</a></span></li></ul></li><li><span><a href="#Training-Model-Using-All-Default-and-BoxCox-Transformed-features" data-toc-modified-id="Training-Model-Using-All-Default-and-BoxCox-Transformed-features-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Training Model Using All Default and BoxCox Transformed features</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-3.1.1.1"><span class="toc-item-num">3.1.1.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#DecisionTreeClassifier" data-toc-modified-id="DecisionTreeClassifier-3.1.1.2"><span class="toc-item-num">3.1.1.2&nbsp;&nbsp;</span>DecisionTreeClassifier</a></span></li><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-3.1.1.3"><span class="toc-item-num">3.1.1.3&nbsp;&nbsp;</span>RandomForestClassifier</a></span></li><li><span><a href="#GradientBoostingClassifier" data-toc-modified-id="GradientBoostingClassifier-3.1.1.4"><span class="toc-item-num">3.1.1.4&nbsp;&nbsp;</span>GradientBoostingClassifier</a></span></li><li><span><a href="#xgboost" data-toc-modified-id="xgboost-3.1.1.5"><span class="toc-item-num">3.1.1.5&nbsp;&nbsp;</span>xgboost</a></span></li><li><span><a href="#lightgbm" data-toc-modified-id="lightgbm-3.1.1.6"><span class="toc-item-num">3.1.1.6&nbsp;&nbsp;</span>lightgbm</a></span></li><li><span><a href="#Catboost" data-toc-modified-id="Catboost-3.1.1.7"><span class="toc-item-num">3.1.1.7&nbsp;&nbsp;</span>Catboost</a></span></li></ul></li><li><span><a href="#Training-Model-Using--Only-BoxCox-Transformed-Scaler" data-toc-modified-id="Training-Model-Using--Only-BoxCox-Transformed-Scaler-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Training Model Using  Only BoxCox Transformed Scaler</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-3.1.2.1"><span class="toc-item-num">3.1.2.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#DecisionTreeClassifier" data-toc-modified-id="DecisionTreeClassifier-3.1.2.2"><span class="toc-item-num">3.1.2.2&nbsp;&nbsp;</span>DecisionTreeClassifier</a></span></li><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-3.1.2.3"><span class="toc-item-num">3.1.2.3&nbsp;&nbsp;</span>RandomForestClassifier</a></span></li><li><span><a href="#GradientBoostingClassifier" data-toc-modified-id="GradientBoostingClassifier-3.1.2.4"><span class="toc-item-num">3.1.2.4&nbsp;&nbsp;</span>GradientBoostingClassifier</a></span></li><li><span><a href="#xgboost" data-toc-modified-id="xgboost-3.1.2.5"><span class="toc-item-num">3.1.2.5&nbsp;&nbsp;</span>xgboost</a></span></li><li><span><a href="#lightgbm" data-toc-modified-id="lightgbm-3.1.2.6"><span class="toc-item-num">3.1.2.6&nbsp;&nbsp;</span>lightgbm</a></span></li><li><span><a href="#Catboost" data-toc-modified-id="Catboost-3.1.2.7"><span class="toc-item-num">3.1.2.7&nbsp;&nbsp;</span>Catboost</a></span></li></ul></li><li><span><a href="#Critique" data-toc-modified-id="Critique-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Critique</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Predicting Mortgage Approvals From Government Data
#
# ## Summary
#
# This is the final capstone project for the [Microsoft Professional Program in Data Science](https://academy.microsoft.com/en-us/professional-program/tracks/data-science/) which emphasizes on developing a final report for the machine learning task which highlights the full cycle of exploratory data analysis from  data, to statistical and machine learning modeling, and finally communicating the results. The objective of this work is to predict whether a mortgage application was accepted or denied according to the given [dataset](https://www.datasciencecapstone.org/competitions/14/mortgage-approvals-from-government-data/data/) which is provided by [DrivenData](https://www.drivendata.org/).

# %% [markdown]
# ### Acknowledgment
#
# My sincere appreciation goes to **DataHack4FI Season 3** for presenting me with the opportunity to improve my knowledge/skills and to achieve an accredited official Microsoft certification (qualification) in data science by enrolling me onto this Microsoft Professional Program in Data Science.

# %% [markdown]
# ## About the Data
#
# ### Features
# There are 21 variables in this dataset which is adapted from the Federal Financial Institutions Examination Council's (FFIEC). Each row in the dataset represents a HMDA-reported loan application, and the dataset we are working with covers one particular year.
#
# source: [info](https://www.datasciencecapstone.org/competitions/14/mortgage-approvals-from-government-data/page/44/).
#
# The variables are as follows:
#
# #### PROPERTY LOCATION
# > * **msa_md** (categorical) - A categorical with no ordering indicating Metropolitan Statistical Area/Metropolitan Division where a value of -1 indicates a missing value.
# > * **state_code** (categorical) - A categorical with no ordering indicating the U.S. state where a value of -1 indicates a missing value.
# > * **county_code** (categorical) - A categorical with no ordering indicating the county where a value of -1 indicates a missing value.
# #### LOAN INFORMATION
# > * **lender** (categorical) - A categorical with no ordering indicating which of the lenders was the authority in approving or denying this loan.
# > * **loan_amount** (int) - Size of the requested loan in thousands of dollars.
# > * **loan_type** (categorical) - Indicates whether the loan granted, applied for, or purchased was conventional, government-guaranteed, or government-insured; available values are:
# >> 1 -- Conventional (any loan other than FHA, VA, FSA, or RHS loans).
# >> 2 -- FHA-insured (Federal Housing Administration).
# >> 3 -- VA-guaranteed (Veterans Administration).
# >> 4 -- FSA/RHS (Farm Service Agency or Rural Housing Service).
# > * **property_type** (categorical) - Indicates whether the loan or application was for a one-to-four-family dwelling (other than manufactured housing), manufactured housing, or multifamily dwelling; available values are:
# >> 1 -- One to four-family (other than manufactured housing).
# >> 2 -- Manufactured housing.
# >> 3 -- Multifamily.
# > * **loan_purpose** (categorical) - Indicates whether the purpose of the loan or application was for home purchase, home improvement, or refinancing; available values are:
# >> 1 -- Home purchase.
# >> 2 -- Home improvement.
# >> 3 -- Refinancing.
# > * **occupancy** (categorical) - Indicates whether the property to which the loan application relates will be the owner's principal dwelling; available values are:
# >> 1 -- Owner-occupied as a principal dwelling.
# >> 2 -- Not owner-occupied.
# >> 3 -- Not applicable.
# > * **preapproval** (categorical) - Indicate whether the application or loan involved a request for a pre-approval. of a home purchase loan; available values are:
# >> 1 -- Preapproval was requested.
# >> 2 -- Preapproval was not requested.
# >> 3 -- Not applicable.
# #### APPLICANT INFORMATION
# > * **applicant_income** (int) - In thousands of dollars.
# > * **applicant_ethnicity** (categorical) - Ethnicity of the applicant; available values are:
# >> 1 -- Hispanic or Latino.
# >> 2 -- Not Hispanic or Latino.
# >> 3 -- Information not provided by applicant in mail, Internet, or telephone pplication.
# >> 4 -- Not applicable.
# >> 5 -- No co-applicant.
# > * **applicant_race** (categorical) - Race of the applicant; available values are:
# >> 1 -- American Indian or Alaska Native.
# >> 2 -- Asian.
# >> 3 -- Black or African American.
# >> 4 -- Native Hawaiian or Other Pacific Islander.
# >> 5 -- White.
# >> 6 -- Information not provided by applicant in mail, Internet, or telephone application.
# >> 7 -- Not applicable.
# >> 8 -- No co-applicant.
# > * **applicant_sex** (categorical) - Sex of the applicant; available values are:
# >> 1 -- Male.
# >> 2 -- Female.
# >> 3 -- Information not provided by applicant in mail, Internet, or telephone application
# >> 4 or 5 -- Not applicable.
# > * **co_applicant** (bool) - Indicates whether there is a co-applicant (often a spouse) or not.
# #### CENSUS INFORMATION
# > * **population** - Total population in tract.
# > * **minority_population_pct** - Percentage of minority population to total population for tract.
# > * **ffiecmedian_family_income** - FFIEC Median family income in dollars for the MSA/MD in which the tract is located (adjusted annually by FFIEC).
# > * **tract_to_msa_md_income_pct** - % of tract median family income compared to MSA/MD median family income.
# > * **number_of_owner-occupied_units** - Number of dwellings, including individual condominiums, that are lived in by the owner.
# > * **number_of_1_to_4_family_units** - Dwellings that are built to house fewer than 5 families.
# #### TARGET VARIABLE
# > * **accepted** - Indicates whether the mortgage application was accepted (successfully originated) with a value of 1 or denied with a value of 0.

# %% [markdown]
# ## Performance Metric
# The performance metric for our classification task is the accuracy (also known as "classification rate"). It is the fraction of predictions our model got right. For binary classification, accuracy can be calculated in terms of positives and negatives as follows:
#
# **Accuracy =(TP+TN)/(TP+TN+FP+FN)**
# > where;
# > * TP ---> True Positives
# > * TN ---> True Negatives
# > * FP ---> False Positives
# > * FN ---> False Negatives.

# %% [markdown]
# ### Load Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype
from pylab import rcParams
import seaborn as sb
sb.set_style('darkgrid')
rcParams['figure.figsize'] = 8,8
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# #### Import the data

# %%
train_values = pd.read_csv("../CAPSTONE_2019/train_values.csv")
train_labels = pd.read_csv("../CAPSTONE_2019/train_labels.csv")
test_values = pd.read_csv("../CAPSTONE_2019/test_values.csv")
submission = pd.read_csv("../CAPSTONE_2019/submission_format.csv")
print('+*+-'*20)
print("The train values consist of {} observations and {} feature columns.".format(train_values.shape[0],train_values.shape[1]))
print("The train labels consist of {} observations and a single target variable.".format(train_labels.shape[0]))
print("The test values consists of {} observations and {} feature columns.".format(test_values.shape[0],test_values.shape[1]))
print('+*+-'*20)
# Out:
# +*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-
# The train values consist of 500000 observations and 22 feature columns.
# The train labels consist of 500000 observations and a single target variable.
# The test values consists of 500000 observations and 22 feature columns.
# +*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-+*+-

# %%
# displaying the first 10 rows of the training values
train_values.head(10)
# Out:
#    row_id  loan_type  property_type  loan_purpose  occupancy  loan_amount  \
# 0       0          3              1             1          1         70.0
# 1       1          1              1             3          1        178.0
# 2       2          2              1             3          1        163.0
# 3       3          1              1             1          1        155.0
# 4       4          1              1             1          1        305.0
# 5       5          1              1             3          1        133.0
# 6       6          3              1             1          1        240.0
# 7       7          2              1             1          1        210.0
# 8       8          1              1             3          2        209.0
# 9       9          1              1             3          1        197.0
#
#    preapproval  msa_md  state_code  county_code      ...       applicant_sex  \
# ...

# %%
#  The train values dataset is originally made up of 22 columns with 500,000 observations.
#  13 columns of the dataset have int64 data type, 8 of them are float64 and a single column is boolean data type
train_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 22 columns):
# row_id                            500000 non-null int64
# loan_type                         500000 non-null int64
# property_type                     500000 non-null int64
# loan_purpose                      500000 non-null int64
# occupancy                         500000 non-null int64
# loan_amount                       500000 non-null float64
# preapproval                       500000 non-null int64
# msa_md                            500000 non-null int64
# state_code                        500000 non-null int64
# county_code                       500000 non-null int64
# applicant_ethnicity               500000 non-null int64
# applicant_race                    500000 non-null int64
# applicant_sex                     500000 non-null int64
# applicant_income                  460052 non-null float64
# population                        477535 non-null float64
# ...

# %%
# checking for total number of missing values in each column within the train_values
train_values.isnull().sum()
# Out:
# row_id                                0
# loan_type                             0
# property_type                         0
# loan_purpose                          0
# occupancy                             0
# loan_amount                           0
# preapproval                           0
# msa_md                                0
# state_code                            0
# county_code                           0
# applicant_ethnicity                   0
# applicant_race                        0
# applicant_sex                         0
# applicant_income                  39948
# population                        22465
# minority_population_pct           22466
# ffiecmedian_family_income         22440
# tract_to_msa_md_income_pct        22514
# number_of_owner-occupied_units    22565
# number_of_1_to_4_family_units     22530
# lender                                0
# co_applicant                          0
# dtype: int64

# %%
# It is observed that none but 7 columns which are of the float64 data type have missing values. 
'''
We check out the percentage of missing data from these columns so we could decide on whether to replace them or 
remove them completely from the data.
'''
col = ['applicant_income','population','minority_population_pct','ffiecmedian_family_income',
'tract_to_msa_md_income_pct','number_of_owner-occupied_units','number_of_1_to_4_family_units']

print('')
# This prints out the percentage of data that is missing in each column that has missing values
print('+-'*35)
print('Percentage of missing values in each column in the train_values data:')
print('+-'*35)
print((train_values[col].isnull().sum()/(train_values.shape[0])*100))
# Out:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# Percentage of missing values in each column in the train_values data:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# applicant_income                  7.9896
# population                        4.4930
# minority_population_pct           4.4932
# ffiecmedian_family_income         4.4880
# tract_to_msa_md_income_pct        4.5028
# number_of_owner-occupied_units    4.5130
# number_of_1_to_4_family_units     4.5060
# dtype: float64

# %%
# From the data description, it is noted that msa_md,county_code and state_code also have missing values indicated 
# by -1. So we check to know the total number of values which were missing from these columns
missing_msa_md = train_values.msa_md[train_values.msa_md == -1].count()
print('+-'*35)
print("Total missing values for msa_md column is: {}".format(missing_msa_md))
print("This forms about {:.1f}% of the total county_code data".format(missing_msa_md/(train_values.shape[0])*100))
print('+-'*35)
# Out:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# Total missing values for msa_md column is: 76982
# This forms about 15.4% of the total county_code data
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
missing_county_code = train_values.county_code[train_values.county_code == -1].count()
print('+-'*35)
print("Total missing values for county_code column is: {}".format(missing_county_code))
print("This forms about {:.1f}% of the total county_code data".format(missing_county_code/(train_values.shape[0])*100))
print('+-'*35)
# Out:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# Total missing values for county_code column is: 20466
# This forms about 4.1% of the total county_code data
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
missing_state_code = train_values.state_code[train_values.state_code == -1].count()
print('+-'*35)
print("Total missing values for state_code column is: {}".format(missing_state_code))
print("This forms about {:.1f}% of the total state_code data".format(missing_state_code/(train_values.shape[0])*100))
print('+-'*35)
# Out:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# Total missing values for state_code column is: 19132
# This forms about 3.8% of the total state_code data
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# Descriptive statistics of the train_values, transposed to prevent horizontal scrolling 
train_values.describe().T
# Out:
#                                    count           mean            std  \
# row_id                          500000.0  249999.500000  144337.711634
# loan_type                       500000.0       1.366276       0.690555
# property_type                   500000.0       1.047650       0.231404
# loan_purpose                    500000.0       2.066810       0.948371
# occupancy                       500000.0       1.109590       0.326092
# loan_amount                     500000.0     221.753158     590.641648
# preapproval                     500000.0       2.764722       0.543061
# msa_md                          500000.0     181.606972     138.464169
# state_code                      500000.0      23.726924      15.982768
# county_code                     500000.0     144.542062     100.243612
# applicant_ethnicity             500000.0       2.036228       0.511351
# applicant_race                  500000.0       4.786586       1.024927
# ...

# %%
# displaying the first 10 rows of the training labels
train_labels.head(10)
# Out:
#    row_id  accepted
# 0       0         1
# 1       1         0
# 2       2         1
# 3       3         1
# 4       4         1
# 5       5         1
# 6       6         1
# 7       7         1
# 8       8         1
# 9       9         0

# %%
# The train labels dataset contains 2 columns with 500,000 observations.
#  Both columns are of the int64 data type
train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 2 columns):
# row_id      500000 non-null int64
# accepted    500000 non-null int64
# dtypes: int64(2)
# memory usage: 7.6 MB

# %%
# check for missing data in our training labels
# None of the two columns has missing data
train_labels.isnull().sum()
# Out:
# row_id      0
# accepted    0
# dtype: int64

# %% [markdown]
# # DATA EXPLORATION & Visualization

# %% [markdown]
# ### Univariate Analysis (Categorical features) Using the unmodified train_values

# %% [markdown]
# The categorical features are:
# 1. loan_type
# 2. property_type
# 3. loan_purpose
# 3. occupancy
# 5. preapproval
# 6. msa_md
# 7. state_code
# 8. county_code
# 9. applicant_ethnicity
# 10. applicant_race
# 11. applicant_sex
# 12. co_applicant

# %%
cat_feat = []
for i in train_values.columns[1:]:
    if train_values[i].dtype != float:
        cat_feat.append(i)
fig=plt.subplots(figsize=(20,20))
for i, j in enumerate(cat_feat):
    plt.subplot(4, 4, i+1)
    sb.countplot(x=j,data = train_values)
    plt.title("Boxplot of" +''+ j)
plt.savefig('catfeat.jpg')  

# print("+-+"*38)
# print("It is very obvious from our visualization that all the numeric features contain \
# extreme values as against the target variable")
# print("+-+"*35)

# %%
# 1 -- Conventional (any loan other than FHA, VA, FSA, or RHS loans). 
# 2 -- FHA-insured (Federal Housing Administration). 
# 3 -- VA-guaranteed (Veterans Administration). 
# 4 -- FSA/RHS (Farm Service Agency or Rural Housing Service).
# proportions of loan types for each type of loan
print(train_values['loan_type'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['loan_type'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['loan_type'],orient='vertical')
print('+-+-'*28)
# print('')
print("A little above 74.2% of the loan applications constituted conventional loans i.e. any \
loan other than FHA, VA,FSA, or RHS loans. The Federal Housing Administration (FHA-insured) loan represnted a little \
above 16.5% and Veterans Administration (VA-guaranteed) loans, also formed about 7.9% of the total loan types. \
The Farm service Agency or Rural Housing Service (FSA/RHS) formed a little above 1.4% of the total loan applications.")
print('+-+-'*28)
# Out:
# 1    370827
# 2     82430
# 3     39521
# 4      7222
# Name: loan_type, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# A little above 74.2% of the loan applications constituted conventional loans i.e. any loan other than FHA, VA,FSA, or RHS loans. The Federal Housing Administration (FHA-insured) loan represnted a little above 16.5% and Veterans Administration (VA-guaranteed) loans, also formed about 7.9% of the total loan types. The Farm service Agency or Rural Housing Service (FSA/RHS) formed a little above 1.4% of the total loan applications.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# proportions of property_type for each level of property
# 1 -- One to four-family (other than manufactured housing). 
# 2 -- Manufactured housing. 
# 3 -- Multifamily.
print(train_values['property_type'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['property_type'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['property_type'],orient='vertical')
print('+-+-'*28)
print('About 95.6% of the loan applications were for One to four-family dwelling (other than manufactured housing). \
Around 3.9% of the applications were for manufactured housing, 0.41 % for multifamily dwelling.')
print('+-+-'*28)
# Out:
# 1    478217
# 2     19741
# 3      2042
# Name: property_type, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# About 95.6% of the loan applications were for One to four-family dwelling (other than manufactured housing). Around 3.9% of the applications were for manufactured housing, 0.41 % for multifamily dwelling.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# proportions of loan_purpose for each level of loan purpose
# 1 -- Home purchase. 
# 2 -- Home improvement. 
# 3 -- Refinancing.
print(train_values['loan_purpose'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['loan_purpose'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['loan_purpose'],orient='vertical')
print('+-+-'*28)
print('About 48.5% of loan applicants did apply for the loans for the purpose of refinancing other loans. \
Around 41.8% also  did so for the purpose of home purchasing, and a little below 9.6% applied for the loans \
to improve their homes.')
print('+-+-'*28)
# Out:
# 3    242670
# 1    209265
# 2     48065
# Name: loan_purpose, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# About 48.5% of loan applicants did apply for the loans for the purpose of refinancing other loans. Around 41.8% also  did so for the purpose of home purchasing, and a little below 9.6% applied for the loans to improve their homes.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# proportions of occupancy for each level occupancy
# 1 -- Owner-occupied as a principal dwelling. 
# 2 -- Not owner-occupied. 
# 3 -- Not applicable.
print(train_values['occupancy'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['occupancy'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['occupancy'],orient='vertical')
print('+-+-'*28)
print('Over 89.5% of the loan applications related to properties in which the applicants occupied as their principal \
dwelling. 10.1% of the properties were not owner-occupied and a little below 0.44% of applicants do not relate with \
the properties, hence, not applicable.')
print('+-+-'*28)
# Out:
# 1    447394
# 2     50417
# 3      2189
# Name: occupancy, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# Over 89.5% of the loan applications related to properties in which the applicants occupied as their principal dwelling. 10.1% of the properties were not owner-occupied and a little below 0.44% of applicants do not relate with the properties, hence, not applicable.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# proportions of preapproval for each level of the preapproval
# 1 -- Preapproval was requested. 
# 2 -- Preapproval was not requested. 
# 3 -- Not applicable.
print(train_values['preapproval'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['preapproval'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['preapproval'],orient='vertical')
print('+-+-'*28)
print('About 5.7% of loan applicants for home purchase loan did request for pre-approval. In about 12.0% of the \
applications no pre-approval was requested. No indication for pre-approval was shown by the majority of the \
applicants who represent about 82.2% of the applicants.')
print('+-+-'*28)
# Out:
# 3    411109
# 2     60143
# 1     28748
# Name: preapproval, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# About 5.7% of loan applicants for home purchase loan did request for pre-approval. In about 12.0% of the applications no pre-approval was requested. No indication for pre-approval was shown by the majority of the applicants who represent about 82.2% of the applicants.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# proportions of applicant_ethnicity for each level of the applicant_ethnicity
# 1 -- Hispanic or Latino. 
# 2 -- Not Hispanic or Latino. 
# 3 -- Information not provided by applicant in mail, Internet, or telephone pplication. 
# 4 -- Not applicable. 
print(train_values['applicant_ethnicity'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['applicant_ethnicity'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['applicant_ethnicity'],orient='vertical')
print('+-+-'*28)
print('About 77.2% of the loan applicants were neither Hispanic nor Latino. About 11.5% of the applicants did not \
provide information about their ethnicity either through their mail, internet or telephone applications. \
About 10.2% of applicants were either Hispanic or Latino and the remaining 1.2% of the applicants were not \
applicable')
print('+-+-'*28)
# Out:
# 2    386061
# 3     57298
# 1     50822
# 4      5819
# Name: applicant_ethnicity, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# About 77.2% of the loan applicants were neither Hispanic nor Latino. About 11.5% of the applicants did not provide information about their ethnicity either through their mail, internet or telephone applications. About 10.2% of applicants were either Hispanic or Latino and the remaining 1.2% of the applicants were not applicable
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# proportions of applicant_race for each level of the applicant_race
# 1 -- American Indian or Alaska Native. 
# 2 -- Asian. 
# 3 -- Black or African American. 
# 4 -- Native Hawaiian or Other Pacific Islander. 
# 5 -- White. 
# 6 -- Information not provided by applicant in mail, Internet, or telephone application. 
# 7 -- Not applicable. 
# 8 -- No co-applicant.
print(train_values['applicant_race'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['applicant_race'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['applicant_race'],orient='vertical')
print('+-+-'*28)
print('Whites form the majority of loan applicants representing 72.3% of the loan applications. Blacks or African \
Americans follow next with about 8.1% of the loan applications. Asians constitute about 5.2% and native \
Hawaiian or other pacific Islanders forming about 0.5% of the total applicants. About 12.0% of loan applicants did \
not provide information about their race during their mail, internet or telephone applications.')
print('+-+-'*28)
# Out:
# 5    361538
# 6     59862
# 3     40495
# 2     25756
# 7      5678
# 1      4332
# 4      2339
# Name: applicant_race, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# Whites form the majority of loan applicants representing 72.3% of the loan applications. Blacks or African Americans follow next with about 8.1% of the loan applications. Asians constitute about 5.2% and native Hawaiian or other pacific Islanders forming about 0.5% of the total applicants. About 12.0% of loan applicants did not provide information about their race during their mail, internet or telephone applications.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# proportions of applicant_sex for each level of the applicant_race
# 1 -- Male. 
# 2 -- Female. 
# 3 -- Information not provided by applicant in mail, Internet, or telephone application 
# 4 or 5 -- Not applicable.
print(train_values['applicant_sex'].value_counts())
plt.figure(figsize=(15,5))
plt.subplot(121)
train_values['applicant_sex'].value_counts(normalize=True).plot(kind='bar')
plt.subplot(122)
sb.violinplot(x=train_values['applicant_sex'],orient='vertical')
print('+-+-'*28)
print('63.2% of loan applicants are males. Females form about 28.6% and the remaining 8.2% did not reveal \
their gender status during the application process.')
print('+-+-'*28)
# Out:
# 1    315806
# 2    142876
# 3     35643
# 4      5675
# Name: applicant_sex, dtype: int64
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# 63.2% of loan applicants are males. Females form about 28.6% and the remaining 8.2% did not reveal their gender status during the application process.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %% [markdown]
# ### Univariate Analysis (Numeric features) Using unmodified train_values

# %% [markdown]
# The numeric variables are:
# 1. loan_amount
# 2. applicant_income
# 3. population
# 4. minority_population_pct
# 5. ffiecmedian_family_income
# 6. tract_to_msa_md_income_pct
# 7. number_of_owner-occupied_units
# 8. number_of_1_to_4_family_units

# %%
print(train_values['loan_amount'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# loan_amount
plt.subplot(121)
train_values['loan_amount'].plot.hist(range=(0,1000))
plt.xlabel('loan_amount')
plt.title("histogram of loan_amount")

plt.subplot(122)
# loan_amount
sb.distplot(train_values['loan_amount'],bins=10,kde=True,rug=True,hist=False)
plt.xlabel('loan_amount')
plt.title("Kde of loan_amount")
plt.savefig('loanamt.jpg')
plt.show()
# Out:
# count    500000.000000
# mean        221.753158
# std         590.641648
# min           1.000000
# 25%          93.000000
# 50%         162.000000
# 75%         266.000000
# max      100878.000000
# Name: loan_amount, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
print(train_values['applicant_income'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# applicant_income
plt.subplot(121)
train_values['applicant_income'].dropna().plot.hist(range=(0,1000),color='green')
plt.xlabel('applicant_income')
plt.title("histogram of applicant_income")

plt.subplot(122)
# applicant_income
sb.distplot(train_values['applicant_income'].dropna(),bins=10,kde=True,rug=True,hist=False,color='green')
plt.xlabel('applicant_income')
plt.title("Kde of applicant_income")
plt.savefig('applicant_income.jpg')
plt.show()
# Out:
# count    460052.000000
# mean        102.389521
# std         153.534496
# min           1.000000
# 25%          47.000000
# 50%          74.000000
# 75%         117.000000
# max       10139.000000
# Name: applicant_income, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
# population
print(train_values['population'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# population
plt.subplot(121)
train_values['population'].dropna().plot.hist(color='orange')
plt.xlabel('population')
plt.title("histogram of population")

plt.subplot(122)
# population
sb.distplot(train_values['population'].dropna(),kde=True,rug=True,hist=True,color='orange')
plt.xlabel('population')
plt.title("Kde of population")
plt.savefig('population.jpg')
plt.show()
# Out:
# count    477535.000000
# mean       5416.833956
# std        2728.144999
# min          14.000000
# 25%        3744.000000
# 50%        4975.000000
# 75%        6467.000000
# max       37097.000000
# Name: population, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
# minority_population_pct
print(train_values['minority_population_pct'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# minority_population_pct
plt.subplot(121)
train_values['minority_population_pct'].dropna().plot.hist(color='purple')
plt.xlabel('minority_population_pct')
plt.title("histogram of minority_population_pct")

plt.subplot(122)
# minority_population_pct
sb.distplot(train_values['minority_population_pct'].dropna(),kde=True,rug=True,hist=True,color='purple')
plt.xlabel('minority_population_pct')
plt.title("Kde of minority_population_pct")
plt.savefig('minopopulation.jpg')
plt.show()
# Out:
# count    477534.000000
# mean         31.617310
# std          26.333938
# min           0.534000
# 25%          10.700000
# 50%          22.901000
# 75%          46.020000
# max         100.000000
# Name: minority_population_pct, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
# ffiecmedian_family_income
print(train_values['ffiecmedian_family_income'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# ffiecmedian_family_income
plt.subplot(121)
train_values['ffiecmedian_family_income'].dropna().plot.hist(color='brown')
plt.xlabel('ffiecmedian_family_income')
plt.title("histogram of ffiecmedian_family_income")

plt.subplot(122)
# minority_population_pct
sb.distplot(train_values['ffiecmedian_family_income'].dropna(),kde=True,rug=True,hist=True,color='brown')
plt.xlabel('ffiecmedian_family_income')
plt.title("Kde of ffiecmedian_family_income")
plt.savefig('ffiecmedian.jpg')
plt.show()
# Out:
# count    477560.000000
# mean      69235.603298
# std       14810.058791
# min       17858.000000
# 25%       59731.000000
# 50%       67526.000000
# 75%       75351.000000
# max      125248.000000
# Name: ffiecmedian_family_income, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
# number_of_owner-occupied_units
print(train_values['number_of_owner-occupied_units'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# number_of_owner-occupied_units
plt.subplot(121)
train_values['number_of_owner-occupied_units'].dropna().plot.hist(color='teal')
plt.xlabel('number_of_owner-occupied_units')
plt.title("histogram of number_of_owner-occupied_units")

plt.subplot(122)
# minority_population_pct
sb.distplot(train_values['number_of_owner-occupied_units'].dropna(),kde=True,rug=True,hist=True,color='teal')
plt.xlabel('number_of_owner-occupied_units')
plt.title("Kde of number_of_owner-occupied_units")
plt.savefig('number_of_owne.jpg')
plt.show()
# Out:
# count    477435.000000
# mean       1427.718282
# std         737.559511
# min           4.000000
# 25%         944.000000
# 50%        1327.000000
# 75%        1780.000000
# max        8771.000000
# Name: number_of_owner-occupied_units, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
# tract_to_msa_md_income_pct
print(train_values['tract_to_msa_md_income_pct'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# tract_to_msa_md_income_pct
plt.subplot(121)
train_values['tract_to_msa_md_income_pct'].dropna().plot.hist(color='olive')
plt.xlabel('tract_to_msa_md_income_pct')
plt.title("histogram of tract_to_msa_md_income_pct")

plt.subplot(122)
# minority_population_pct
sb.distplot(train_values['tract_to_msa_md_income_pct'].dropna(),kde=True,rug=True,hist=True,color='olive')
plt.xlabel('tract_to_msa_md_income_pct')
plt.title("Kde of tract_to_msa_md_income_pct")
plt.savefig('tract_to_msa.jpg')
plt.show()

plt.savefig('tract_to_msa.jpg')
# Out:
# count    477486.000000
# mean         91.832624
# std          14.210924
# min           3.981000
# 25%          88.067250
# 50%         100.000000
# 75%         100.000000
# max         100.000000
# Name: tract_to_msa_md_income_pct, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
# number_of_1_to_4_family_units
print(train_values['number_of_1_to_4_family_units'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# number_of_1_to_4_family_units
plt.subplot(121)
train_values['number_of_1_to_4_family_units'].dropna().plot.hist(color='crimson')
plt.xlabel('number_of_1_to_4_family_units')
plt.title("histogram of number_of_1_to_4_family_units")

plt.subplot(122)
# number_of_1_to_4_family_units
sb.distplot(train_values['number_of_1_to_4_family_units'].dropna(),kde=True,rug=True,hist=True,color='crimson')
plt.xlabel('number_of_1_to_4_family_units')
plt.title("Kde of number_of_1_to_4_family_units")
plt.savefig('number_of_1_to_4.jpg')
plt.show()
# Out:
# count    477470.000000
# mean       1886.147065
# std         914.123744
# min           1.000000
# 25%        1301.000000
# 50%        1753.000000
# 75%        2309.000000
# max       13623.000000
# Name: number_of_1_to_4_family_units, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# From the above histograms and distributions of the 8 numeric (float) features, it is noted that only one feature (ie. tract_to_msa_md_income_pct) out of the 8 features is left skewed. The remaining 7 are all right skewed. This simply implies that the numeric columns all deviate from the normal bell-shape anticipated, and perhaps would require feature transformation.

# %% [markdown]
# ### Bivariate Analysis Using the merged Data
#
# Since the training values and training labels are separated, we will merge the two and make a new dataframe. We will be using the row_id as the key.

# %%
# merging our training values with the training labels using row id as ur key
DF = train_values.merge(train_labels,left_on='row_id',right_on='row_id',how='left')
DF1 = DF.set_index('row_id')
# create a copy of the merged data and work
df = DF1.copy()
df.shape
# Out:
# (500000, 22)

# %% [markdown]
# #### Visualization of numeric features with the target variable

# %%
numeric_feat = ['loan_amount','applicant_income','population',
                'minority_population_pct','ffiecmedian_family_income',
                'tract_to_msa_md_income_pct','number_of_owner-occupied_units','number_of_1_to_4_family_units']

fig=plt.subplots(figsize=(20,20))
for i, j in enumerate(numeric_feat):
    plt.subplot(4, 2, i+1)
    sb.boxplot(x='accepted',y=j,data = df)
    plt.title("Frequency of" +''+ j +''+ "by Acceptance")
plt.savefig('accepted_vrs_numeric.jpg')  

print("+-+"*38)
print("It is very obvious from our visualization that all the numeric features contain \
extreme values as against the target variable")
print("+-+"*35)
# Out:
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# It is very obvious from our visualization that all the numeric features contain extreme values as against the target variable
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %% [markdown]
# #### Loan acceptance rates across ethnicity and gender

# %%
print(pd.crosstab(df['applicant_ethnicity'],df['accepted']))
ethnicity = pd.crosstab(df['applicant_ethnicity'],df['accepted'])
ethnicity.div(ethnicity.sum(1).astype(float), axis=0).plot(kind="bar", stacked=False, figsize=(9,5))
plt.xlabel('applicant_ethnicity')
p = plt.ylabel('Percentage')
print('+++'*35)
print("Applicants whose ethinicity was 'Not applicable' (where applicant_ethnicity= 4) have a higher loan \
acceptance rate on average than Hispanic or Latino (where applicant_ethnicity= 1).")
print('+++'*35)
# Out:
# accepted                  0       1
# applicant_ethnicity
# 1                     29100   21722
# 2                    185109  200952
# 3                     34451   22847
# 4                      1226    4593
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Applicants whose ethinicity was 'Not applicable' (where applicant_ethnicity= 4) have a higher loan acceptance rate on average than Hispanic or Latino (where applicant_ethnicity= 1).
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
print(pd.crosstab(df['applicant_sex'],df['accepted']))
gender = pd.crosstab(df['applicant_sex'],df['accepted'])
gender.div(gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=False, figsize=(9,5))
plt.xlabel('applicant_sex')
plt.ylabel('Percentage')
print('+++'*37)
print('Male appliants (where applicant_sex=1) have a higher loan acceptance rate on average than female \
applicants (where applicant_sex=2).')
print('+++'*37)
# Out:
# accepted            0       1
# applicant_sex
# 1              151327  164479
# 2               76231   66645
# 3               21170   14473
# 4                1158    4517
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Male appliants (where applicant_sex=1) have a higher loan acceptance rate on average than female applicants (where applicant_sex=2).
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Applicant income and loan amount

# %%
# Applicant income and loan amount for only applicants in state 45
df1 = df[df['state_code'] == 45]
print(df1.shape)
# df1.head()
# Out:
# (4638, 22)

# %%
# Regression plot to show the relationship between the two features
plt.figure(figsize=(10,7))
sb.regplot(x='applicant_income',y='loan_amount',data=df1)
plt.title("Regression plot showing relationship between applicant_income and loan_amount")
# plt.savefig('regplot.jpg')
plt.show()
print('+++'*37)
print('The correlation between applicant_income and loan_amount is {:0.2f}'.format(df1['applicant_income'].\
corr(df1['loan_amount'])))
print(' A higher applicant income is associated with a higher loan amount, on average..')
print('+++'*37)
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# The correlation between applicant_income and loan_amount is 0.63
#  A higher applicant income is associated with a higher loan amount, on average..
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Loan acceptance across counties in state 48

# %%
# Loan acceptance across counties limiting just to state 48 and ignoring where county is missing 
# (missing value being -1)
df2 = df[(df['state_code']==48) & (df['county_code'] != -1)]
print(df2.shape)
# df2.head()
# Out:
# (15711, 22)

# %%
# print(pd.crosstab(df2['county_code'],df2['accepted']).T)
county = pd.crosstab(df2['county_code'],df2['accepted'])
county.div(county.sum(1).astype(float), axis=0).plot(kind="bar", stacked=False, figsize=(15,6))
plt.xlabel('county_code')
p = plt.ylabel('Percentage')
print('++'*55)
print('In state 48, the average rate of loan acceptance across counties varies substantially, ranging from \
around 30% to around 70%.')
print('++'*55)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# In state 48, the average rate of loan acceptance across counties varies substantially, ranging from around 30% to around 70%.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Loan types across states looking just at states 2 and 4

# %%
# Loan types across states looking just at states 2 and 4
df3 = df[(df['state_code']==2) | (df['state_code'] == 4)]
print(df3.shape)
# df3.head()
# Out:
# (45367, 22)

# %%
print(df3.groupby(['state_code','loan_type'])['accepted'].value_counts(normalize=True))
loantyp = df3.groupby(['state_code','loan_type'])['accepted'].value_counts(normalize=True)
loantyp.div(loantyp.sum(0).astype(float)).plot(kind="bar", stacked=False, figsize=(14,5))
plt.xlabel('loan_type')
p = plt.ylabel('Percentage')
print('++'*55)
print('For each of the four loan types, the loan acceptance rate in state 2 is lower than for the corrsponding \
loan type in state 4.')
print('++'*55)
# Out:
# state_code  loan_type  accepted
# 2           1          0           0.564196
#                        1           0.435804
#             2          1           0.503708
#                        0           0.496292
#             3          1           0.531802
#                        0           0.468198
#             4          0           0.538760
#                        1           0.461240
# 4           1          1           0.569992
#                        0           0.430008
#             2          1           0.554178
#                        0           0.445822
#             3          1           0.639456
#                        0           0.360544
#             4          1           0.617647
#                        0           0.382353
# Name: accepted, dtype: float64
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...

# %% [markdown]
# # Data Cleaning & Feature Engineering

# %% [markdown]
# #### Dealing with Missing Values in train data

# %%
# checking for missing values in our merged data
df.isnull().sum()
# Out:
# loan_type                             0
# property_type                         0
# loan_purpose                          0
# occupancy                             0
# loan_amount                           0
# preapproval                           0
# msa_md                                0
# state_code                            0
# county_code                           0
# applicant_ethnicity                   0
# applicant_race                        0
# applicant_sex                         0
# applicant_income                  39948
# population                        22465
# minority_population_pct           22466
# ffiecmedian_family_income         22440
# tract_to_msa_md_income_pct        22514
# number_of_owner-occupied_units    22565
# number_of_1_to_4_family_units     22530
# lender                                0
# co_applicant                          0
# accepted                              0
# dtype: int64

# %%
col = ['applicant_income','population','minority_population_pct','ffiecmedian_family_income',
'tract_to_msa_md_income_pct','number_of_owner-occupied_units','number_of_1_to_4_family_units']
# This prints out the percentage of data that is missing in each column that has missing values
print('Percentage of missing values in each column in the training data:')
print('+-'*25)
print(df[col].isnull().sum()/(df.shape[0])*100)
# Out:
# Percentage of missing values in each column in the training data:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# applicant_income                  7.9896
# population                        4.4930
# minority_population_pct           4.4932
# ffiecmedian_family_income         4.4880
# tract_to_msa_md_income_pct        4.5028
# number_of_owner-occupied_units    4.5130
# number_of_1_to_4_family_units     4.5060
# dtype: float64

# %% [markdown]
# We will replace missing values in the training data (df) in each numeric column with its median.

# %%
# replacing missing values with the applicant_income mean in the training data
df['applicant_income'].fillna(df['applicant_income'].median(),inplace=True)
# replacing missing values with the population mean
df['population'].fillna(df['population'].median(),inplace=True)
# replacing missing values with the minority_population_pct mean
df['minority_population_pct'].fillna(df['minority_population_pct'].median(),inplace=True)
# replacing missing values with the ffiecmedian_family_income mean
df['ffiecmedian_family_income'].fillna(df['ffiecmedian_family_income'].median(),inplace=True)
# replacing missing values with the tract_to_msa_md_income_pct mean
df['tract_to_msa_md_income_pct'].fillna(df['tract_to_msa_md_income_pct'].median(),inplace=True)
# replacing missing values with the number_of_owner-occupied_units mean
df['number_of_owner-occupied_units'].fillna(df['number_of_owner-occupied_units'].median(),inplace=True)
# replacing missing values with the number_of_1_to_4_family_units mean
df['number_of_1_to_4_family_units'].fillna(df['number_of_1_to_4_family_units'].median(),inplace=True)
print('+-'*30)
print("We have replaced the missing values with their median values")
print('+-'*30)
# Out:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# We have replaced the missing values with their median values
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %%
# Data is clean and without missing values now
df.isnull().sum()
# Out:
# loan_type                         0
# property_type                     0
# loan_purpose                      0
# occupancy                         0
# loan_amount                       0
# preapproval                       0
# msa_md                            0
# state_code                        0
# county_code                       0
# applicant_ethnicity               0
# applicant_race                    0
# applicant_sex                     0
# applicant_income                  0
# population                        0
# minority_population_pct           0
# ffiecmedian_family_income         0
# tract_to_msa_md_income_pct        0
# number_of_owner-occupied_units    0
# number_of_1_to_4_family_units     0
# lender                            0
# co_applicant                      0
# accepted                          0
# dtype: int64

# %% [markdown]
# #### Save the train data with replaced missing values to a csv file

# %%
# Save the train data to a csv after replacing missing values
# df.to_csv('df_clean.csv', index = False, header = True)

# %% [markdown]
# We will maintain the missing values in msa_md, county_code and state_code as indicated by -1

# %%
test_values.isnull().sum()
# Out:
# row_id                                0
# loan_type                             0
# property_type                         0
# loan_purpose                          0
# occupancy                             0
# loan_amount                           0
# preapproval                           0
# msa_md                                0
# state_code                            0
# county_code                           0
# applicant_ethnicity                   0
# applicant_race                        0
# applicant_sex                         0
# applicant_income                  40141
# population                        22480
# minority_population_pct           22482
# ffiecmedian_family_income         22453
# tract_to_msa_md_income_pct        22517
# number_of_owner-occupied_units    22574
# number_of_1_to_4_family_units     22550
# lender                                0
# co_applicant                          0
# dtype: int64

# %%
col = ['applicant_income','population','minority_population_pct','ffiecmedian_family_income',
'tract_to_msa_md_income_pct','number_of_owner-occupied_units','number_of_1_to_4_family_units']
# This prints out the percentage of data that is missing in each column that has missing values
print('Percentage of missing values in each column in the testdata:')
print('+-'*25)
print(test_values[col].isnull().sum()/(test_values.shape[0])*100)
# Out:
# Percentage of missing values in each column in the testdata:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# applicant_income                  8.0282
# population                        4.4960
# minority_population_pct           4.4964
# ffiecmedian_family_income         4.4906
# tract_to_msa_md_income_pct        4.5034
# number_of_owner-occupied_units    4.5148
# number_of_1_to_4_family_units     4.5100
# dtype: float64

# %%
# replacing missing values with the applicant_income mean for testdata
test_values['applicant_income'].fillna(test_values['applicant_income'].median(),inplace=True)
# replacing missing values with the population mean
test_values['population'].fillna(test_values['population'].median(),inplace=True)
# replacing missing values with the minority_population_pct mean
test_values['minority_population_pct'].fillna(test_values['minority_population_pct'].median(),inplace=True)
# replacing missing values with the ffiecmedian_family_income mean
test_values['ffiecmedian_family_income'].fillna(test_values['ffiecmedian_family_income'].median(),inplace=True)
# replacing missing values with the tract_to_msa_md_income_pct mean
test_values['tract_to_msa_md_income_pct'].fillna(test_values['tract_to_msa_md_income_pct'].median(),inplace=True)
# replacing missing values with the number_of_owner-occupied_units mean
test_values['number_of_owner-occupied_units'].fillna(test_values['number_of_owner-occupied_units'].median(),inplace=True)
# replacing missing values with the number_of_1_to_4_family_units mean
test_values['number_of_1_to_4_family_units'].fillna(test_values['number_of_1_to_4_family_units'].median(),inplace=True)

# %%
# We check for duplicate values and remove them
print('+-'*40)
print('There are {} duplicates values in the training data'.format(df.duplicated().sum()))
# Remove duplicates.
df = df.drop_duplicates()
print('There are {} observations in the train data after removing all duplicates.'.format(df.shape[0]))
print('+-'*40)
# Out:
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
# There are 43 duplicates values in the training data
# There are 499957 observations in the train data after removing all duplicates.
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-

# %% [markdown]
# #### Create a new column, income_to_loan_ratio

# %%
df['income_to_loan_ratio'] = (df['applicant_income'])/(df['loan_amount'])
test_values['income_to_loan_ratio'] = (test_values['applicant_income'])/(test_values['loan_amount'])

# %%
print(df['income_to_loan_ratio'].describe())
print('+++'*15)
plt.figure(2,figsize=(15,5))
# loan_amount
plt.subplot(121)
df['income_to_loan_ratio'].plot.hist(range=(0,5),color= 'red')
plt.xlabel('income_to_loan_ratio')
plt.title("histogram of income_to_loan_ratio")

plt.subplot(122)
# loan_amount
sb.distplot(df['income_to_loan_ratio'],bins=5,kde=True,rug=True,hist=False,color='red')
plt.xlabel('income_to_loan_ratio')
plt.title("Kde of income_to_loan_ratio")
plt.savefig('income_to_loan_ratio.jpg')
plt.show()
# Out:
# count    499957.000000
# mean          1.135359
# std           5.236097
# min           0.000513
# 25%           0.300000
# 50%           0.441176
# 75%           0.733945
# max        1237.375000
# Name: income_to_loan_ratio, dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++

# %%
# from scipy.stats import boxcox
# df['boxcox_loan_amount'] = boxcox(df['loan_amount'],lmbda=-0.025)
# test_values['boxcox_loan_amount'] = boxcox(test_values['loan_amount'],lmbda=-0.025)
# plt.figure(figsize=(16,16))
# plt.subplot(221)
# df['loan_amount'].plot.hist(range=(0,1000))
# plt.xlabel('loan_amount')
# plt.title('Histogram of original loan amount')
# plt.subplot(222)
# df['boxcox_loan_amount'].plot.hist(color='brown')
# plt.xlabel('boxcox_loan_amount')
# plt.title('Histogram of transformed loan amount')


# df['boxcox_applicant_income'] = boxcox(df['applicant_income'],lmbda=-0.025)
# test_values['boxcox_applicant_income'] = boxcox(test_values['applicant_income'],lmbda=-0.025)
# plt.subplot(223)
# df['applicant_income'].plot.hist(range=(0,1000),color='green')
# plt.xlabel('loan_amount')
# plt.title('Histogram of original applicant_income')
# plt.subplot(224)
# df['boxcox_applicant_income'].plot.hist(color='magenta')
# plt.xlabel('boxcox_applicant_income')
# plt.title('Histogram of transformed applicant_income')
# plt.savefig('trasLA.jpg')
# plt.show()

# %%
print(df.shape)
print(test_values.shape)
# Out:
# (499957, 23)
# (500000, 23)

# %%
print(df['accepted'].value_counts(normalize=True))
print('+-+'*38)
print('The target variable is balanced with a 50% between the number of accepted mortgage applications and \
those denied')
print('+-+'*38)
total = float(len(df))
plt.figure(figsize=(8,5))
ax = sb.countplot(df['accepted'],palette='cubehelix')
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:.2f}%'.format((height/total)*100),
            ha="center") 
plt.savefig('targ.jpg')
plt.legend()
plt.show()
# Out:
# 1    0.500271
# 0    0.499729
# Name: accepted, dtype: float64
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# The target variable is balanced with a 50% between the number of accepted mortgage applications and those denied
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# No handles with labels found to put in legend.

# %% [markdown]
# #### Correlation and heatmap for df_clean data

# %%
df.corr()
# Out:
#                                 loan_type  property_type  loan_purpose  \
# loan_type                        1.000000      -0.065202     -0.121240
# property_type                   -0.065202       1.000000     -0.114674
# loan_purpose                    -0.121240      -0.114674      1.000000
# occupancy                       -0.158963       0.156145      0.002122
# loan_amount                     -0.018506       0.135931     -0.002859
# preapproval                     -0.133059       0.046027      0.487285
# msa_md                          -0.024357      -0.076078      0.072387
# state_code                      -0.047087      -0.017650      0.118136
# county_code                     -0.016265      -0.007447      0.058018
# applicant_ethnicity             -0.050181       0.131211      0.023344
# applicant_race                  -0.016692       0.063431      0.021658
# applicant_sex                   -0.072430       0.106805      0.014374
# ...

# %%
# finding the relationship between the variables
cor =df.corr()
sb.heatmap(cor, xticklabels=cor.columns.values, yticklabels=cor.columns.values, 
           annot = True, annot_kws={'size':12})
heat_map=plt.gcf()
heat_map.set_size_inches(20,15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('correlation_plot.png')
plt.show()

# %% [markdown]
# Due to the very strong correlation between number_of_1_to_4_family_units and population and also between number_of_owner-occupied_units and population and number_of_1_to_4_family_units, We have decided to drop number_of_owner-occupied_units and population.

# %% [markdown]
# ## Model Building and Selection

# %% [markdown]
# I will now explore a number of classification algorithms. Their performance when compared to each other may give a first indication on what the most promising algorithms for the dataset are. I can then focus on these to furtehr optimize the hyperparameters.
#
# For now, I include the following algorithms:
#
# * logistic regression (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html">Sklearn</a>)
# * decison tree classifier (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html">Sklearn</a>)
# * random forest classifier (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html">Sklearn</a>)
# * gradient boosting tree classifier (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html">Sklearn</a>)
# * xgboosting classifier (<a href="https://xgboost.readthedocs.io/en/latest/python/python_api.html">XGBoost Python API reference</a>)
# * LightGBM (<a href="https://lightgbm.readthedocs.io/en/latest/">LightGBM</a>)
# * LightGBM (<a href="https://catboost.ai/docs/">Yandex Technology</a>)
#
# All algorithm are first run using their default values.

# %%
# Splitting my cleaned  train data into train and validate
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier,Pool, cv
from scipy.stats import uniform 
from scipy.stats import randint 
from datetime import datetime
import xgboost
import time

# %%
dropcols = ['accepted','population','number_of_owner-occupied_units']#,'boxcox_applicant_income','boxcox_loan_amount']
           #,'number_of_owner-occupied_units','number_of_1_to_4_family_units']
#dropcols = ['accepted','population','minority_population_pct','ffiecmedian_family_income',
#'tract_to_msa_md_income_pct','number_of_owner-occupied_units','number_of_1_to_4_family_units','lender']
X = df.drop(columns= dropcols,axis=1)
y = df['accepted']
print(X.shape)
print(y.shape)

test_values.drop(columns=['row_id','population','number_of_owner-occupied_units'],axis=1,inplace=True)
print(test_values.shape)
# Out:
# (499957, 20)
# (499957,)
# (500000, 20)

# %%
cat_features = np.where(X.dtypes != np.float)[0]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state=1)
print(X_train.shape)
print(y_train.shape)
print('+-'*7)
print(X_test.shape)
print(y_test.shape)
print('+-'*7)
print(test_values.shape)
# Out:
# (374967, 20)
# (374967,)
# +-+-+-+-+-+-+-
# (124990, 20)
# (124990,)
# +-+-+-+-+-+-+-
# (500000, 20)

# %% [markdown]
# #### Logistic Regression

# %%
logit = LogisticRegression(class_weight='balanced', random_state=111, n_jobs=1)
before = time.time()
logitmodel = logit.fit(X_train,y_train)
logpred = logitmodel.predict(X_test)
print('+-+'*35)
print("The accuracy score for the logistic regression is %.2f" % (accuracy_score(logpred,y_test)*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('Classification Report')
print('+-+'*15)
print(classification_report(logpred,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(logpred,y_test)
df_cm = pd.DataFrame(cm, index=['Denied','Accepted'], columns=['Denied','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Logistic Regression') 
plt.show()
# Out:
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# The accuracy score for the logistic regression is 62.68
# Time taken to execute algorithm is : 67.02 s
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Classification Report
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
#              precision    recall  f1-score   support
#
#           0       0.65      0.62      0.63     65179
#           1       0.61      0.63      0.62     59811
#
# avg / total       0.63      0.63      0.63    124990
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Confusion Matrix
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %% [markdown]
# #### DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(max_depth=13) 
before = time.time()
dtcmodel = dtc.fit(X_train,y_train)
dtcpred = dtcmodel.predict(X_test)
print('+-+'*35)
print("The accuracy score for the decision tree classifier is %.2f" % (accuracy_score(dtcpred,y_test)*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
# print('The accuracy score for logistic regression is {}'.format(accuracy_score(y_val,ypred)*100))
print('+-+'*35)
print('')
# Out:
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# The accuracy score for the decision tree classifier is 68.68
# Time taken to execute algorithm is : 18.75 s
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(dtcpred,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(dtcpred,y_test)
df_cm = pd.DataFrame(cm, index=['Denied','Accepted'], columns=['Denied','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='Set2')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Decision Tree Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(dtcmodel.feature_importances_, index=X.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from DecisionTreeClassifier')
plt.show()
# Out:
# Classification Report
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
#              precision    recall  f1-score   support
#
#           0       0.58      0.73      0.65     49370
#           1       0.79      0.66      0.72     75620
#
# avg / total       0.71      0.69      0.69    124990
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Confusion Matrix
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %% [markdown]
# #### RandomForestClassifier

# %%
rand = RandomForestClassifier(bootstrap=True,
                              criterion = "entropy",
                              n_jobs=-1,
                              max_depth=25,
                              n_estimators=700,
                              max_features=0.5,
                              random_state=0)
randmodel = rand.fit(X_train,y_train)
randpred = randmodel.predict(X_test)
# rfPredictproba = randomForest.predict_proba(X_test)[:,1] #for ROC curve
rfAccuracy = accuracy_score(y_test,randpred)
roc_score = roc_auc_score(y_test,randpred)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the random forest classifier is %.2f with an roc_score of %.2f" % (rfAccuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')
# Out:
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# The accuracy score for the random forest classifier is 70.36 with an roc_score of 0.70
# Time taken to execute algorithm is : 2418.96 s
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(randpred,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(randpred,y_test)
df_cm = pd.DataFrame(cm, index=['Denied','Accepted'], columns=['Denied','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='Pastel2_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Random Forest Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(randmodel.feature_importances_, index=X.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Random Forest Classifier')
plt.show()
# Out:
# Classification Report
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
#              precision    recall  f1-score   support
#
#           0       0.62      0.74      0.68     52371
#           1       0.78      0.68      0.73     72619
#
# avg / total       0.72      0.70      0.71    124990
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Confusion Matrix
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %% [markdown]
# #### GradientBoostingClassifier

# %%
Grad = GradientBoostingClassifier(n_estimators=600, 
                                  max_depth=7, 
                                  random_state=1
                                 )

gradmodel1 = Grad.fit(X_train,y_train)
gradpred1 = gradmodel1.predict(X_test)
# rfPredictproba = randomForest.predict_proba(X_test)[:,1] #for ROC curve
Accuracy = accuracy_score(y_test,gradpred1)
roc_score = roc_auc_score(y_test,gradpred1)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the GradientBoostingClassifier is %.2f with an roc_score of %.2f" %(Accuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')
# Out:
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# The accuracy score for the GradientBoostingClassifier is 72.08 with an roc_score of 0.72
# Time taken to execute algorithm is : 7431.15 s
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(gradpred1,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(gradpred1,y_test)
df_cm = pd.DataFrame(cm, index=['Denied','Accepted'], columns=['Denied','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='coolwarm_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for GradientBoosting Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(gradmodel1.feature_importances_, index=X.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from GradientBoostingClassifier')
plt.show()
# Out:
# Classification Report
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
#              precision    recall  f1-score   support
#
#           0       0.66      0.75      0.70     54832
#           1       0.78      0.70      0.74     70158
#
# avg / total       0.73      0.72      0.72    124990
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Confusion Matrix
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %% [markdown]
# #### xgboost

# %%
xgb = XGBClassifier(objective="binary:logistic", 
                    learning_rate=0.01,
                    max_depth=25, 
                    gamma=10, 
                    n_estimators=1000,
                    seed=111
                   )

before = time.time()
xgbmodel1 = xgb.fit(X_train,y_train, eval_set=[(X_test, y_test)],eval_metric="auc", 
                   early_stopping_rounds=20,verbose=100)

xgbpred1 = xgbmodel1.predict(X_test)

Accuracy = accuracy_score(y_test,xgbpred1)
roc_score = roc_auc_score(y_test,xgbpred1)
print('+-+'*35)
print("The accuracy score for the xgboost classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
# Out:
# [0]	validation_0-auc:0.755505
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [100]	validation_0-auc:0.776229
# [200]	validation_0-auc:0.781163
# [300]	validation_0-auc:0.785056
# [400]	validation_0-auc:0.790407
# [500]	validation_0-auc:0.794268
# [600]	validation_0-auc:0.795756
# [700]	validation_0-auc:0.796559
# Stopping. Best iteration:
# [763]	validation_0-auc:0.797008
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# The accuracy score for the xgboost classifier is 72.04 with an roc_score of 0.72
# Time taken to execute algorithm is : 8619.76 s
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# ...

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(xgbpred1,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(xgbpred1,y_test)
df_cm = pd.DataFrame(cm, index=['Denied','Accepted'], columns=['Denied','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='gist_earth')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Xgboost Classifier') 
plt.show()
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(xgbmodel1.feature_importances_, index=X.columns)
feat_importances.nlargest(21).sort_values().plot(kind='barh')
plt.title('Feature Importance from Xgboost Classifier')
plt.show()
# Out:
# Classification Report
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
#              precision    recall  f1-score   support
#
#           0       0.66      0.75      0.70     54363
#           1       0.78      0.70      0.74     70627
#
# avg / total       0.73      0.72      0.72    124990
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Confusion Matrix
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %% [markdown]
# #### lightgbm

# %%
lgbm = LGBMClassifier(n_estimators=1000, 
                      objective='binary',
                      boosting_type='gbdt',
                      class_weight='balanced',
                      learning_rate=0.05,
                      max_depth = 25,
                      reg_alpha = 0.1, 
                      reg_lambda=0.1,
                      subsample = 0.8,
                      verbose=200,
                      custom_metric = ['Logloss', 'AUC'],
                      cat_features= cat_features,
                      n_jobs = -1, 
                      random_state=1)#max_depth = 11,

before = time.time()

lgbmodel1 = lgbm.fit(X_train, y_train, eval_set = [(X_test, y_test)], 
                     eval_metric = 'accuracy',early_stopping_rounds = 20, verbose = 100)

lgbmpred1 = lgbmodel1.predict(X_test)
Accuracy = accuracy_score(y_test,lgbmpred1)
roc_score = roc_auc_score(y_test,lgbmpred1)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the light gradient boosting classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print(after - before)
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')
# Out:
# Training until validation scores don't improve for 20 rounds.
# [100]	valid_0's binary_logloss: 0.566137
# [200]	valid_0's binary_logloss: 0.555828
# [300]	valid_0's binary_logloss: 0.55205
# [400]	valid_0's binary_logloss: 0.549746
# [500]	valid_0's binary_logloss: 0.548205
# [600]	valid_0's binary_logloss: 0.547224
# [700]	valid_0's binary_logloss: 0.546022
# [800]	valid_0's binary_logloss: 0.545149
# [900]	valid_0's binary_logloss: 0.544549
# [1000]	valid_0's binary_logloss: 0.5438
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's binary_logloss: 0.543797
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# The accuracy score for the light gradient boosting classifier is 71.65 with an roc_score of 0.72
# 125.35170650482178
# Time taken to execute algorithm is : 125.35 s
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# ...

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(lgbmpred1,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(lgbmpred1,y_test)
df_cm = pd.DataFrame(cm, index=['Denied','Accepted'], columns=['Denied','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='gnuplot2_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Light GradientBoosting Classifier') 
plt.show()
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(lgbmodel1.feature_importances_, index=X.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Light Gradient Boosting Classifier')
plt.show()
# Out:
# Classification Report
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
#              precision    recall  f1-score   support
#
#           0       0.65      0.75      0.69     53786
#           1       0.79      0.69      0.74     71204
#
# avg / total       0.73      0.72      0.72    124990
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Confusion Matrix
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %% [markdown]
# #### Chosen Model

# %% [markdown]
# #### Catboost

# %%
CATBOOST = CatBoostClassifier(
    random_seed=100,#100,
    iterations=1000,
    learning_rate=0.373,
    boosting_type='Ordered',#Ordered
    bootstrap_type='Bernoulli',
    verbose = 100,
    subsample=0.8,
    one_hot_max_size=100,#set bigger value
    rsm=0.8,
    eval_metric='Accuracy',
    l2_leaf_reg=8.28,
    leaf_estimation_iterations=8,# calculates leaf values
    max_ctr_complexity=10,
    border_count=32,
    depth=6,
    use_best_model=True,
    custom_metric =['Logloss', 'AUC'],
    snapshot_file='CATBOOST.bkp',#save snapshots which allows the computer to continue from where it was interrupted
    early_stopping_rounds=50)

before = time.time()
CATBOOST_MODEL = CATBOOST.fit(X_train, y_train,eval_set=[(X_test, y_test)],cat_features= cat_features,plot=True)

catpred1 = CATBOOST_MODEL.predict(X_test)

Accuracy = accuracy_score(y_test,catpred1)
roc_score = roc_auc_score(y_test,catpred1)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the light catboost classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
# print("The accuracy score for the catboost algorithm is %.2f" % (accuracy_score(catpred1,np.array(y_test).flatten())*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
# ...

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(catpred1,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(catpred1,y_test)
df_cm = pd.DataFrame(cm, index=['Denied','Accepted'], columns=['Denied','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='viridis_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Catboost Classifier') 
plt.savefig('catboostconfmat.jpg')
plt.show()
plt.figure(figsize=(12,8))    
feat_importances = pd.Series(CATBOOST_MODEL.feature_importances_, index=X.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Catboost Classifier')
plt.savefig('catboost_feat_imp.png')
plt.show()
# Out:
# Classification Report
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.76      0.72     55829
#         1.0       0.78      0.71      0.74     69161
#
# avg / total       0.74      0.73      0.73    124990
#
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+
# Confusion Matrix
# +-++-++-++-++-++-++-++-++-++-++-++-++-++-++-+

# %%
CATBOOST = CatBoostClassifier(
    random_seed=100,#100,
    iterations=1000,
    learning_rate=0.373,
    boosting_type='Ordered',#Ordered
    bootstrap_type='Bernoulli',
    verbose = 100,
    subsample=0.8,
    one_hot_max_size=100,#set bigger value
    rsm=0.8,
    eval_metric='Accuracy',
    l2_leaf_reg=8.28,
    leaf_estimation_iterations=8,# calculates leaf values
    max_ctr_complexity=10,
    border_count=32,
    depth=6,
    use_best_model=False,
    snapshot_file='CATBOOST.bkp',#save snapshots which allows the computer to continue from where it was interrupted
    early_stopping_rounds=50)
CATBOOST_MODEL = CATBOOST.fit(X, y)
# Out:
# 0:	learn: 0.6341845	total: 2.32s	remaining: 38m 41s
# 100:	learn: 0.7044826	total: 3m 34s	remaining: 31m 46s
# 200:	learn: 0.7095030	total: 7m 5s	remaining: 28m 12s
# 300:	learn: 0.7128413	total: 10m 35s	remaining: 24m 34s

# %%
predicted = CATBOOST_MODEL.predict(test_values)
predicted

# %%
submission['accepted'] = predicted
submission.head()

# %%
submission['accepted'] = submission['accepted'].astype(int)
submission.dtypes

# %%
submission.head()

# %%
submission.to_csv('subm_catboost_FINAL_MODEL.csv',index=False,header=True)

# %% [markdown]
# ### Training Model Using All Default and BoxCox Transformed features

# %%
df1 = pd.read_csv('/home/francisanokye/AIMS/BIGDATA/DataHack/CAPSTONE_2019/df_clean_transformed.csv')
df1.head()

# %%
df1.columns

# %%
dropcols = ['accepted']
X2 = df1.drop(columns= dropcols,axis=1)
y2 = df1['accepted']
print(X2.shape)
print(y2.shape)

# %%
X2_train,X2_test,y2_train,y2_test = train_test_split(X2,y2,test_size = 0.30,random_state=1)
print(X2_train.shape)
print(y2_train.shape)
print('+-'*7)
print(X2_test.shape)
print(y2_test.shape)

# %%
# # normalizing data using the robust scaler since the different variables have different scales of measurement
# # scaling with robustscaler
# columns_to_scale = X2.columns.tolist()
# std = RobustScaler()
# std.fit(X2_train)
# X2_train = std.transform(X2_train)
# X2_test = std.transform(X2_test)

# %% [markdown]
# #### Logistic Regression

# %%
logit = LogisticRegression(class_weight='balanced', random_state=1, n_jobs=1)
before = time.time()
logitmodel2 = logit.fit(X2_train,y2_train)
logpred2 = logitmodel2.predict(X2_test)
print('+-+'*35)
print("The accuracy score for the logistic regression is %.2f" % (accuracy_score(logpred2,y2_test)*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)

print('Classification Report')
print('+-+'*15)
print(classification_report(logpred2,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(logpred2,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='Wistia_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Logistic Regression') 
plt.show()

# %% [markdown]
# #### DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(max_depth=13) 
before = time.time()
dtcmodel2 = dtc.fit(X2_train,y2_train)
dtcpred2 = dtcmodel2.predict(X2_test)
print('+-+'*35)
print("The accuracy score for the decision tree classifier is %.2f" % (accuracy_score(dtcpred,y_test)*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
# print('The accuracy score for logistic regression is {}'.format(accuracy_score(y_val,ypred)*100))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(dtcpred2,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(dtcpred2,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='ocean_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Decision Tree Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(dtcmodel2.feature_importances_, index=X2.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from DecisionTreeClassifier')
plt.show()

# %% [markdown]
# #### RandomForestClassifier

# %%
rand = RandomForestClassifier(bootstrap=True,
                              criterion = "entropy",
                              n_jobs=-1,
                              max_depth=25,
                              n_estimators=600,
                              random_state=0)
randmodel2 = rand.fit(X2_train,y2_train)
randpred2 = randmodel.predict(X2_test)
# rfPredictproba = randomForest.predict_proba(X_test)[:,1] #for ROC curve
rfAccuracy = accuracy_score(y2_test,randpred2)
roc_score = roc_auc_score(y2_test,randpred2)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the random forest classifier is %.2f with an roc_score of %.2f" % (rfAccuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(randpred2,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(randpred2,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='terrain')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Random Forest Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(randmodel2.feature_importances_, index=X2.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Random Forest Classifier')
plt.show()

# %% [markdown]
# #### GradientBoostingClassifier

# %%
Grad = GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=600, 
                                 subsample=1.0, criterion='friedman_mse', min_samples_split=2, 
                                 min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=7, 
                                 min_impurity_decrease=0.0, min_impurity_split=None, init=None, 
                                 random_state=1, max_features=None,  
                                 max_leaf_nodes=None, warm_start=False, presort='auto')

gradmodel2 = Grad.fit(X2_train,y2_train)
gradpred2 = gradmodel2.predict(X2_test)
# rfPredictproba = randomForest.predict_proba(X_test)[:,1] #for ROC curve
Accuracy = accuracy_score(y2_test,gradpred2)
roc_score = roc_auc_score(y2_test,gradpred2)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the GradientBoostingClassifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(gradpred2,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(gradpred2,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Gradient Boosting Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(gradmodel2.feature_importances_, index=X2.columns)
feat_importances.nlargest().sort_values().plot(kind='barh')
plt.title('Feature Importance from GradientBoostingClassifier')
plt.show()

# %% [markdown]
# #### xgboost

# %%
xgb = XGBClassifier(objective="binary:logistic", 
                    learning_rate=0.01,
                    max_depth=25, 
                    gamma=10, 
                    n_estimators=1000,
                    seed=111
                   )

before = time.time()
xgbmodel2 = xgb.fit(X2_train,y2_train, eval_set=[(X2_test, y2_test)],eval_metric="auc", 
                   early_stopping_rounds=20,verbose=100)

xgbpred2 = xgbmodel2.predict(X2_test)

Accuracy = accuracy_score(y2_test,xgbpred2)
roc_score = roc_auc_score(y2_test,xgbpred2)
print('+-+'*35)
print("The accuracy score for the xgboost classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(xgbpred2,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(xgbpred2,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='seismic_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Xgboost Classifier') 
plt.show()
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(xgbmodel2.feature_importances_, index=X2.columns)
feat_importances.nlargest(21).plot(kind='bar')
plt.title('Feature Importance from Xgboost Classifier')
plt.show()

# %% [markdown]
# #### lightgbm

# %%
lgbm = LGBMClassifier(n_estimators=1000, 
                      objective='binary',
                      boosting_type='gbdt',
                      class_weight='balanced',
                      learning_rate=0.05,
                      max_depth = 25,
                      reg_alpha = 0.1, 
                      reg_lambda=0.1,
                      subsample = 0.8,
                      verbose=200,
                      custom_metric = ['Logloss', 'AUC'],
                      cat_features= cat_features,
                      n_jobs = -1, 
                      random_state=1)#max_depth = 11,

before = time.time()

lgbmodel2 = lgbm.fit(X2_train, y2_train, eval_set = [(X2_test, y2_test)], 
                     eval_metric = 'accuracy',early_stopping_rounds = 20, verbose = 100)

lgbmpred2 = lgbmodel2.predict(X2_test)
Accuracy = accuracy_score(y2_test,lgbmpred2)
roc_score = roc_auc_score(y2_test,lgbmpred2)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the light gradient boosting classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print(after - before)
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(lgbmpred2,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(lgbmpred2,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='RdYlGn')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Light Gradient Boosting Classifier') 
plt.show()
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(lgbmodel2.feature_importances_, index=X2.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Light Gradient Boosting Classifier')
plt.show()

# %% [markdown]
# #### Catboost

# %%
CATBOOST = CatBoostClassifier(
    random_seed=100,
    iterations=1000,
    learning_rate=0.373,
    boosting_type='Ordered',#Ordered
    bootstrap_type='Bernoulli',
    verbose = 100,
    subsample=0.8,
    one_hot_max_size=100,#set bigger value
    rsm=0.8,
    eval_metric='Accuracy',
    l2_leaf_reg=8.28,
    leaf_estimation_iterations=8,# calculates leaf values
    max_ctr_complexity=10,
    border_count=32,
    depth=6,
    use_best_model=True,
    custom_metric =['Logloss', 'AUC'],
    snapshot_file='CATBOOST.bkp',#save snapshots which allows the computer to continue from where it was interrupted
    early_stopping_rounds=50)

before = time.time()
CatB = CATBOOST.fit(X2_train, y2_train,eval_set=[(X2_test, y2_test)],cat_features= cat_features,plot=True)

catpred2 = CatB.predict(X2_test)

Accuracy = accuracy_score(y2_test,catpred2)
roc_score = roc_auc_score(y2_test,catpred2)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the light catboost classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
# print("The accuracy score for the catboost algorithm is %.2f" % (accuracy_score(catpred1,np.array(y_test).flatten())*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(catpred2,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(catpred2,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='nipy_spectral_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Catboost Classifier') 
plt.show()
plt.figure(figsize=(12,8))    
feat_importances = pd.Series(CatB.feature_importances_, index=X2.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Catboost Classifier')
plt.show()
plt.savefig('catboost_feat_imp.png')

# %%
# submisstion = pd.DataFrame()
# submisstion['row_id'] = X_test['row_id']
# submisstion['accepted'] = model.predict(test_values)
# submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ### Training Model Using  Only BoxCox Transformed Scaler

# %%
dropdefcols = ['accepted','loan_amount','applicant_income','population','minority_population_pct',
            'ffiecmedian_family_income','tract_to_msa_md_income_pct','number_of_owner-occupied_units',
            'number_of_1_to_4_family_units']
X3 = df1.drop(columns= dropdefcols,axis=1)
y3 = df1['accepted']
print(X3.shape)
print(y3.shape)

# %%
X3_train,X3_test,y3_train,y3_test = train_test_split(X3,y3,test_size = 0.25,random_state=1)
print(X3_train.shape)
print(y3_train.shape)
print('+-'*7)
print(X3_test.shape)
print(y3_test.shape)

# %%
# scaling with quantiletransform
std = RobustScaler()
X3_train = std.fit_transform(X3_train)
X3_test = std.transform(X3_test)

# %% [markdown]
# #### Logistic Regression

# %%
logit = LogisticRegression(class_weight='balanced', random_state=1, n_jobs=1)
before = time.time()
logitmodel3 = logit.fit(X3_train,y3_train)
logpred3 = logitmodel3.predict(X3_test)
print('+-+'*35)
print("The accuracy score for the logistic regression is %.2f" % (accuracy_score(logpred3,y3_test)*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)

print('Classification Report')
print('+-+'*15)
print(classification_report(logpred3,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(logpred3,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='jet_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Logistic Regression') 
plt.show()

# %% [markdown]
# #### DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(max_depth=13) 
before = time.time()
dtcmodel3 = dtc.fit(X3_train,y3_train)
dtcpred3 = dtcmodel3.predict(X3_test)
print('+-+'*35)
print("The accuracy score for the decision tree classifier is %.2f" % (accuracy_score(dtcpred3,y3_test)*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
# print('The accuracy score for logistic regression is {}'.format(accuracy_score(y_val,ypred)*100))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(dtcpred3,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(dtcpred3,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='tab20c')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Decision Tree Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(dtcmodel3.feature_importances_, index=X3.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from DecisionTreeClassifier')
plt.show()

# %% [markdown]
# #### RandomForestClassifier

# %%
rand = RandomForestClassifier(bootstrap=True,
                              criterion = "entropy",
                              n_jobs=-1,
                              max_depth=25,
                              n_estimators=600,
                              random_state=0)
randmodel3 = rand.fit(X3_train,y3_train)
randpred3 = randmodel3.predict(X3_test)
# rfPredictproba = randomForest.predict_proba(X_test)[:,1] #for ROC curve
rfAccuracy = accuracy_score(y3_test,randpred3)
roc_score = roc_auc_score(y3_test,randpred3)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the random forest classifier is %.2f with an roc_score of %.2f" % (rfAccuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(randpred3,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(randpred3,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='flag_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Random Forest Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(randmodel3.feature_importances_, index=X3.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Random Forest Classifier')
plt.show()

# %% [markdown]
# #### GradientBoostingClassifier

# %%
Grad = GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=600, 
                                 subsample=1.0, criterion='friedman_mse', min_samples_split=2, 
                                 min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=7, 
                                 min_impurity_decrease=0.0, min_impurity_split=None, init=None, 
                                 random_state=1, max_features=None,  
                                 max_leaf_nodes=None, warm_start=False, presort='auto')

gradmodel3 = Grad.fit(X3_train,y3_train)
gradpred3 = gradmodel3.predict(X3_test)
# rfPredictproba = randomForest.predict_proba(X_test)[:,1] #for ROC curve
Accuracy = accuracy_score(y3_test,gradpred3)
roc_score = roc_auc_score(y3_test,gradpred3)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the GradientBoostingClassifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(gradpred3,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(gradpred3,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='vlag')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Gradient Boosting Classifier') 
plt.show()
# plotting feature importance
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(gradmodel3.feature_importances_, index=X3.columns)
feat_importances.nlargest().sort_values().plot(kind='barh')
plt.title('Feature Importance from GradientBoostingClassifier')
plt.show()

# %% [markdown]
# #### xgboost

# %%
xgb = XGBClassifier(objective="binary:logistic", 
                    learning_rate=0.01,
                    max_depth=25, 
                    gamma=10, 
                    n_estimators=1000,
                    seed=111
                   )

before = time.time()
xgbmodel3 = xgb.fit(X3_train,y3_train, eval_set=[(X3_test, y3_test)],eval_metric="auc", 
                   early_stopping_rounds=20,verbose=100)

xgbpred3 = xgbmodel3.predict(X3_test)

Accuracy = accuracy_score(y3_test,xgbpred3)
roc_score = roc_auc_score(y3_test,xgbpred3)
print('+-+'*35)
print("The accuracy score for the xgboost classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(xgbpred3,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(xgbpred3,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='binary_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Xgboost Classifier') 
plt.show()
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(xgbmodel3.feature_importances_, index=X3.columns)
feat_importances.nlargest(21).plot(kind='bar')
plt.title('Feature Importance from Xgboost Classifier')
plt.show()

# %% [markdown]
# #### lightgbm

# %%
lgbm = LGBMClassifier(n_estimators=1000, 
                      objective='binary',
                      boosting_type='gbdt',
                      class_weight='balanced',
                      learning_rate=0.05,
                      max_depth = 25,
                      reg_alpha = 0.1, 
                      reg_lambda=0.1,
                      subsample = 0.8,
                      verbose=200,
                      custom_metric = ['Logloss', 'AUC'],
                      cat_features= cat_features,
                      n_jobs = -1, 
                      random_state=1)#max_depth = 11,

before = time.time()

lgbmodel3 = lgbm.fit(X3_train, y3_train, eval_set = [(X3_test, y3_test)], 
                     eval_metric = 'accuracy',early_stopping_rounds = 20, verbose = 100)

lgbmpred3 = lgbmodel3.predict(X3_test)
Accuracy = accuracy_score(y3_test,lgbmpred3)
roc_score = roc_auc_score(y3_test,lgbmpred3)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the light gradient boosting classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
after = time.time()
print(after - before)
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(lgbmpred3,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(lgbmpred3,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='autumn_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Light Gradient Boosting Classifier') 
plt.show()
plt.figure(figsize=(12,8)) 
feat_importances = pd.Series(lgbmodel3.feature_importances_, index=X3.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Light Gradient Boosting Classifier')
plt.show()

# %% [markdown]
# #### Catboost

# %%
CATBOOST = CatBoostClassifier(
    random_seed=100,
    iterations=1000,
    learning_rate=0.373,
    boosting_type='Ordered',#Ordered
    bootstrap_type='Bernoulli',
    verbose = 100,
    subsample=0.8,
    one_hot_max_size=100,#set bigger value
    rsm=0.8,
    eval_metric='Accuracy',
    l2_leaf_reg=8.28,
    leaf_estimation_iterations=8,# calculates leaf values
    max_ctr_complexity=10,
    border_count=32,
    depth=6,
    use_best_model=True,
    custom_metric =['Logloss', 'AUC'],
    snapshot_file='CATBOOST.bkp',#save snapshots which allows the computer to continue from where it was interrupted
    early_stopping_rounds=50)

before = time.time()
CatB1 = CATBOOST.fit(X3_train, y3_train,eval_set=[(X3_test, y3_test)],cat_features= cat_features,plot=True)

catpred3 = CatB.predict(X3_test)

Accuracy = accuracy_score(y3_test,catpred3)
roc_score = roc_auc_score(y3_test,catpred3)
# print(rfAccuracy)
print('+-+'*35)
print("The accuracy score for the light catboost classifier is %.2f with an roc_score of %.2f" % (Accuracy*100,roc_score))
# print("The accuracy score for the catboost algorithm is %.2f" % (accuracy_score(catpred1,np.array(y_test).flatten())*100))
after = time.time()
print("Time taken to execute algorithm is : {:5.2f} s".format(after - before))
print('+-+'*35)
print('')

# %%
print('Classification Report')
print('+-+'*15)
print(classification_report(catpred3,y_test))
print('+-+'*15)
print('Confusion Matrix')
print('+-+'*15)
cm = confusion_matrix(catpred3,y_test)
df_cm = pd.DataFrame(cm, index=['Not Accepted','Accepted'], columns=['Not Accepted','Accepted'])
plt.figure(figsize=(8,5))
heatmap = sb.heatmap(df_cm, annot=True, fmt="d",cmap='Blues_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Catboost Classifier') 
plt.show()
plt.figure(figsize=(12,8))    
feat_importances = pd.Series(CatB1.feature_importances_, index=X3.columns)
feat_importances.nlargest(22).sort_values().plot(kind='barh')
plt.title('Feature Importance from Catboost Classifier')
plt.show()
plt.savefig('catboost_feat_imp.png')

# %% [markdown]
# Some outliers are clearly skewing the distribution of the loan amount and the plot doesn't give much information in this form : Hence, we truncate the data, using the basic yet really powerful rule : the 68–95–99.7 rule. This rule states that for a normal distribution :
#
# * 68.27% of the values  $\in \mu - \sigma , \mu + \sigma$
# * 95.45% of the values  $\in [\mu - 2\sigma , \mu + 2\sigma]$
# * 99.7% of the values  $\in [\mu - 3\sigma , \mu + 3\sigma]$
#
# where  $\mu$  and  $\sigma$  are the mean and standard deviation of the normal distribution.
#
# temp = train_clean['loan_amount']
#
# plt.figure(figsize=(12,8))
# sb.distplot(temp[~((temp-temp.mean()).abs()>3*temp.std())]);
# plt.ylabel("density estimate", fontsize=16)
# plt.xlabel('loan amount', fontsize=16)
# plt.title("KDE of loan amount (outliers removed)", fontsize=16)
# plt.show();
#
# print('Most of the loan amount are between $1 and $500')
#
# plt.figure(figsize=(15,8))
# sb.boxplot(x='loan_amount', y="loan_type", data=X);
# plt.xlabel("Value of loan", fontsize=16)
# plt.ylabel("Sector", fontsize=16)
# plt.title("loan type' amounts boxplots", fontsize=16)
# plt.show();
#
# For every loan type, we have outlier loans. For example it seems someone asked for a 100k loan for an agriculture project. There are also many 20k, 50k ... loans. But as seen earlier, the mean amount in general is around 500 dollars so we have to get rid of those outliers to obtain better boxplots.
# First, let's see the median loan amount for each sector, this would give an idea about the value to use as a treshold.
#
# round(X.groupby(['loan_type'])['loan_amount'].median(),2)
#
#
# The highest median corresponds to 204 dollars for the loan_type 3. Basically, using a treshold that doubles this value (so 500 dollars) is more than safe and we wouldn't be using much information.
#
# temp = X[X['loan_amount']<500]
# plt.figure(figsize=(15,8))
# sns.boxplot(x='loan_amount', y="loan_type", data=temp)
# plt.xlabel("Value of loan", fontsize=16)
# plt.ylabel("Sector", fontsize=16)
# plt.title("loan types' amounts boxplots", fontsize=16)
# plt.show();
#
# This is obviously better visually ! We can also draw some important conclusions. The median and the inter-quartile for 'Personal Use' are much lower than for any other sector. Education and health are a bit higher compared to other 'standard sectors'.
# Why such information can be considered important ? Well keep in mind throughout this notebook that our final goal is to estimate poverty levels.
# Since the amount of loans aren't the same for all sectors (distribution-wise), it may mean that for example borrowers with Personnal Use are poorer and need a small amout for critical needs. This is not necessarily true but it's indeed an hypothesis we can take advantage of going further.
#
#
#
# lender_countries = lenders.groupby(['country_code']).count()[['permanent_name']].reset_index()
# lender_countries.columns = ['country_code', 'Number of Lenders']
# lender_countries.sort_values(by='Number of Lenders', ascending=False,inplace=True)
# lender_countries.head(7)

# %% [markdown]
# ### Critique
#
# * Our model eliminated a number of Magnitude related attributes such as -mad, -max, -min also a number of Gyro related variables during the variable selection process using domain knowledge. These may be important but this was not tested.  We may want to look at that the next time we do this.
#
# * Variable importance should be investigated in detail - i.e. we really ought to look at how we can use the smaller number of attributes identified as important, to create the model and see what the difference is. Computationally this would be more efficient. We could even use simpler methods like Logistic Regression to do the classification from that point on, using only the reduced set of variables.
